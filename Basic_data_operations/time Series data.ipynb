# %% [markdown]
# # Time series data
#
# data frame are like spread sheets where axis =0 is rows and axis = 1 are columns .
#
# - There are Two types of data
#
# 1) Panel data = which has data of different entities in same panel
#
#
# 2) Longitudanal data = Which has data of same entity but various columns such as Open ,High,Low ,Close
#
# **`General Time series image`**
# ![image.png](attachment:image.png)
#
# ---
# granularity of data can be from 1 second , 1 minute ,1 hour, 1 day etc.
#
# Using 1 second data for machine learning models is more suitable.
#
# cross sectional data of multiple instruments is used.

# %% [markdown]
# #Importing Time Series Data
#
# **`Underlying idea is to import data from various resourses in to data Frames`**
#
# ![image.png](attachment:image.png)
#
# - Dataframe:
#
# It is a 2_dimensional data structure used to atore the data in the form of spread sheets
#
# AXIS 0 = ROWS and AXIS 1 = COLUMNS
#
# The data frames are indexed and are mutable where any arthematic operations can be performed
#
# where cells can contain different datatypes ....these properties are matching the strings
#
# This **Data Frame is a Pandas Object and are most commonly used **

# %% [markdown]
# # Importing DATA from Various resources
#
# ## Importing from Yahoo finance

# %%
import yfinance as yf 
from datetime import datetime 
start = datetime(2017,1,1)
end = datetime(2019,1,1)
data = yf.download('MSFT',start,end)

data.head(10) # perfect way to see you data head
print("*"*50)
data.tail(15) # perfect way to see you data tail
# Out:
# [*********************100%***********************]  1 of 1 completed
# **************************************************
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-10  104.800003  107.980003  103.889999  107.589996  105.733536
# 2018-12-11  109.800003  110.949997  107.440002  108.589996  106.716286
# 2018-12-12  110.889999  111.269997  109.040001  109.080002  107.197845
# 2018-12-13  109.580002  110.870003  108.629997  109.449997  107.561447
# 2018-12-14  108.250000  109.260002  105.500000  106.029999  104.200470
# 2018-12-17  105.410004  105.800003  101.709999  102.889999  101.114647
# 2018-12-18  103.750000  104.510002  102.519997  103.970001  102.176010
# 2018-12-19  103.650002  106.879997  101.349998  103.690002  101.900848
# 2018-12-20  103.050003  104.309998   98.779999  101.510002   99.758461
# 2018-12-21  101.629997  103.000000   97.459999   98.230003   96.535049
# ...

# %% [markdown]
# ## Importing Data from quandl
#
#
# *The option is we can even 1 min data from quantinsti apikey*

# %%
import quandl 
from datetime import datetime 
# from os.path import path
from quantrautil import get_quantinsti_api_key

api_key = get_quantinsti_api_key()
# quandl.read_key(api_key)
quandldata = quandl.get("EOD/AAPL")

doubts in using the quandl code
# Out:
#   File "<ipython-input-28-42a3218b68d4>", line 10
#     doubts in using the quandl code
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Importing data from pandas using yahoo

# %%
import pandas as pd 

from pandas_datareader import data 

data = data.get_data_yahoo('AAPL',start,end)

data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-12-24  151.550003  146.589996  148.149994  146.830002  37169200.0
# 2018-12-26  157.229996  146.720001  148.300003  157.169998  58582500.0
# 2018-12-27  156.770004  150.070007  155.839996  156.149994  53117100.0
# 2018-12-28  158.520004  154.550003  157.500000  156.229996  42291400.0
# 2018-12-31  159.360001  156.479996  158.529999  157.740005  35003500.0
#
#              Adj Close
# Date
# 2018-12-24  144.314041
# 2018-12-26  154.476852
# 2018-12-27  153.474335
# 2018-12-28  153.552979
# 2018-12-31  155.037109

# %% [markdown]
# ## Reading a CSV File in pandas

# %%
import numpy as np 

table = pd.read_csv('https://raw.githubusercontent.com/QuantEcon/lecture-source-py/master/source/_static/lecture_specific/pandas/data/test_pwt.csv')

table.head()

table
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
type (table)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# *Another reason is, once you download a CSV file, it becomes a stable data source as it didn't require the involvement of third party. Fetching data from web sources require third-party access and it might fail if the third party access is unavailable. Also, the restriction on the number of request one can make is also imposed. In case of CSV, it is stored on the local drive and can be accessed without the involvement of the third party. We will see more of this in the Pandas section of our course.*
