# %% [markdown]
# FileName and FilePath
#
#  Absolute filepath and relative filepath
#
#  ![image.png](attachment:image.png)

# %%
# if you want to create a dynamic path please pursue doing this 

'\\'.join(['folder1','folder2','folder3'])
# Out:
# 'folder1\\folder2\\folder3'

# %%
import os

# Os has many useful functions to do operations 

print(os.path.join('folder1','folder2','folder3')) # this gives the output of path pertaining to the operating system 

print(os.sep) # this stores the join variable
# Out:
# folder1\folder2\folder3
# \

# %%
os.getcwd() # if a file name is give it will search in cwd
# Out:
# 'C:\\Users\\ramsu\\ltphd\\execises\\Python-Test\\Python Basic'

# %%
dir(os) # below are the attributes and methods of the functions
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
# ...

# %%
os.chdir('C:\\Users\\ramsu\\ltphd\\execises\\Python-Test')

os.getcwd()
# Out:
# 'C:\\Users\\ramsu\\ltphd\\execises\\Python-Test'

# %%
os.chdir('.\\Python Basic') #please see more examples above picture
print(os.getcwd())
os.chdir('..\\')
os.getcwd()
# Out:
# C:\Users\ramsu\ltphd\execises\Python-Test\Python Basic
# 'C:\\Users\\ramsu\\ltphd\\execises\\Python-Test'

# %%
os.path.isabs('..\\..\\')
# Out:
# False

# %%
os.path.abspath('.//')
# Out:
# 'C:\\Users\\ramsu\\ltphd\\execises\\Python-Test'

# %%
os.path.relpath('.//')
# Out:
# '.'

# %%
os.path.dirname("C:\\Users\\ramsu\\ltphd\\execises\\Python-Test")
# Out:
# 'C:\\Users\\ramsu\\ltphd\\execises'

# %%
os.path.basename("C:\\Users\\ramsu\\ltphd\\execises\\Python-Test")
# Out:
# 'Python-Test'

# %%
os.path.exists('.\\yoyo')
# Out:
# False

# %%
dir(os.path)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_abspath_fallback',
#  '_get_bothseps',
#  '_getfinalpathname',
#  '_getfullpathname',
#  '_getvolumepathname',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdir',
#  'isfile',
#  'islink',
#  'ismount',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
#  'sameopenfile',
#  'samestat',
#  'sep',
#  'split',
#  'splitdrive',
#  'splitext',
#  'stat',
#  'supports_unicode_filenames',
#  'sys']

# %%
os.listdir('..\\') # returns the list in path
# Out:
# ['.ipynb_checkpoints',
#  'camarilla.py',
#  'ex01.py',
#  'ex02.py',
#  'ex021.py',
#  'ex03.py',
#  'ex034.py',
#  'ex035.py',
#  'ex036.py',
#  'ex037.py',
#  'ex04.py',
#  'ex040.py',
#  'ex041.py',
#  'ex05.py',
#  'ex06.py',
#  'ex07.py',
#  'ex08.py',
#  'ex09.py',
#  'ex1.py',
#  'ex10.py',
#  'ex11.py',
#  'ex12.py',
#  'ex13.py',
#  'ex14.py',
#  'ex15.py',
#  'ex16.py',
#  'ex17.py',
#  'ex18.py',
#  'ex19.py',
#  'ex20.py',
#  'ex22.py',
#  'ex23.py',
#  'ex24.py',
#  'ex25.py',
#  'ex26.py',
#  'ex27.py',
#  'ex29.py',
#  'ex30.py',
#  'ex31.py',
#  'ex32.py',
#  'ex33.py',
#  'extrail.py',
#  'language.txt',
#  'mystuff.py',
#  'Python-Test',
#  'Quantinsti',
#  'trail.txt',
#  'trail_1.txt',
#  '__pycache__']

# %%
# finding the size of files in cwd
os.chdir('C:\\Users\\ramsu\\ltphd\\execises')
path = os.getcwd()
if os.path.isdir(path):
    for name in os.listdir(path):
        #print(name)
        path1 = f"{path}\\{name}"
        size =0
        if not os.path.isdir(path1):
            #print(name)
            continue
        size +=os.path.getsize(path1)
print(size)   
print(os.getcwd())
# Out:
# 4096
# C:\Users\ramsu\ltphd\execises

# %%
#os.chdir('.\\Python-Test')
os.mkdir('.\cool')# to make a folder 
os.rmdir('.\cool')

# %% [markdown]
# #### reading and writing files go through exercises 15 to 25 by ltphd

# %%
# example 

path =r'C:\Users\ramsu\ltphd\execises\trail.txt'

fileobject = open(path,'r')
fileobject.read()
fileobject.close()

fileobject = open(path,'w')
fileobject.truncate()
fileobject.write("""i am awesome and 
this is nonsense 
this is great""")
fileobject = open(path,'r')

print(fileobject.read())
fileobject.seek(0)
fileobject.readline()# just reading one line 
fileobject.seek(0)

def read(fileobj,readlist):
    line = fileobj.readline()
    if line:
        line = line.strip('\n')
        line = line.split(' ')
        readlist.append(line)
        return read(fileobj,readlist)
    return readlist
list1 =[]
list1 = read(fileobject,list1)
print(list1)
fileobject.close()
# Out:
# i am awesome and
# this is nonsense
# this is great
# [['i', 'am', 'awesome', 'and', ''], ['this', 'is', 'nonsense', ''], ['this', 'is', 'great']]

# %%
import shelve 

file = shelve.open(r'C:\Users\ramsu\ltphd\execises\Python-Test\Python Basic\trail')

file['cat'] =['uabuhsuihfd',"iuahsiudha",'iuabsyfdh',"uhawduih"] #this creates database files

# %%
# copying and moving 

# using shutil module 

# shutil.copy(file,location)
# shutil.copytree(folder,location)
# shutil.move(source,destination)
# shutil.rmtree(source) # to remove a non empty directory

# importing send2trash rather than directly deleting it 

#send2trash.send2trash(source)

# %%
# using os.walk() to walk through a directory tree

for i,j,k in os.walk(os.getcwd()):
    print(i,'>>foldername') 
    print(j,">>subfoldername")
    print(k,">>filename ")
# Out:
# C:\Users\ramsu\ltphd\execises\Python-Test >>foldername
# ['.git', '.ipynb_checkpoints', 'Basic_data_operations', 'Numpy', 'Pandas', 'Python Basic'] >>subfoldername
# ['quantrautil.py', 'README.md'] >>filename
# C:\Users\ramsu\ltphd\execises\Python-Test\.git >>foldername
# ['hooks', 'info', 'logs', 'objects', 'refs'] >>subfoldername
# ['COMMIT_EDITMSG', 'config', 'description', 'HEAD', 'index', 'packed-refs'] >>filename
# C:\Users\ramsu\ltphd\execises\Python-Test\.git\hooks >>foldername
# [] >>subfoldername
# ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'update.sample'] >>filename
# C:\Users\ramsu\ltphd\execises\Python-Test\.git\info >>foldername
# [] >>subfoldername
# ['exclude'] >>filename
# C:\Users\ramsu\ltphd\execises\Python-Test\.git\logs >>foldername
# ['refs'] >>subfoldername
# ...
