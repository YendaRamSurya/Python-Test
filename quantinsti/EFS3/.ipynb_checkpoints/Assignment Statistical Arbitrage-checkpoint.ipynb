# %% [markdown]
# # Notebook Instructions
# <i>You can run the notebook document sequentially (one cell a time) by pressing <b> shift + enter</b>. While a cell is running, a [*] will display on the left. When it has been run, a number will display indicating the order in which it was run in the notebook [8].</i>
#
# <i>Enter edit mode by pressing <b>`Enter`</b> or using the mouse to click on a cell's editor area. Edit mode is indicated by a green cell border and a prompt showing in the editor area.</i>

# %% [markdown]
# # Assignment
#
# In this assignment, you will learn to interpret the ADF test results and create a mean reversion strategy on triplets.
#
# The steps followed are
# 1. Import the libraries and the data
# 2. Find the hedge ratio
# 3. Create the spread
# 4. ADF Test
# 5. Mean reversion strategy
# 6. Plot the profit and loss (PnL)

# %% [markdown]
# ## 1. Import the libraries and the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The code reads the csv file using the read_csv function
#
# Instruction:
# 1. Replace the `...` with `GLD.csv`, `GDX.csv` and `USO.csv` in the below cell

# %%
x = pd.read_csv(r"C:\Users\NIVE\ltphd\execises\Python-Test\quantinsti\EFS3\GLD.csv", index_col=0)['Adj Close']
y = pd.read_csv(r"C:\Users\NIVE\ltphd\execises\Python-Test\quantinsti\EFS3\GDX.csv", index_col=0)['Adj Close']
z = pd.read_csv(r"C:\Users\NIVE\ltphd\execises\Python-Test\quantinsti\EFS3\USO.csv", index_col=0)['Adj Close']

df = pd.concat([x, y, z], axis=1)
df.columns = ['GLD', 'GDX', 'USO']
df.index = pd.to_datetime(df.index)

(df.pct_change()+1).cumprod().plot(figsize=(10, 5))
plt.ylabel("Percentage Change")
plt.show()

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 583 entries, 2017-01-03 to 2019-04-29
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GLD     583 non-null    float64
#  1   GDX     583 non-null    float64
#  2   USO     583 non-null    float64
# dtypes: float64(3)
# memory usage: 18.2 KB

# %% [markdown]
# ## 2. Find the hedge ratio
#
# Instructions
# 1. y is GLD and x1 is GDX and x2 is USO. Replace `..1..` with `GLD`, `..2..` with `GDX`, and `..3..` with `USO`.
# 2. To find the hedge ratio, we will only use first 90 days of data. Replace `..4..` and `..5..` with `90`.

# %%
from statsmodels.api import OLS
model = OLS(df['GLD'].iloc[:90], df[['GDX', 'USO']].iloc[:90])
model = model.fit()
print('The hedge ratio for GDX and USO are')
l1 = model.params
print(l1)
# Out:
# The hedge ratio for GDX and USO are
# GDX    4.783232
# USO    0.727756
# dtype: float64

# %% [markdown]
# ## 3. Create the spread
#
# The spread is formed as GLD - m1 * GDX - m2 * USO. The `model.params[0]` stores m1 and `model.params[1]` stores m2.
#
# Instruction
# 1. Compute the spread

# %%
df['spread'] = df['GLD']-l1[0]*df['GDX']-l1[1]*df['USO']

# %%
print('The spread is: GLD - %f * GDX - %f * USO' %
      (model.params[0], model.params[1]))
# Plot the spread
df.spread.plot(figsize=(10, 5))
plt.ylabel("Spread")
plt.show()
# Out:
# The spread is: GLD - 4.783232 * GDX - 0.727756 * USO

# %% [markdown]
# ### 4. ADF Test
#
# We determine the spread is cointegrated using adfuller method.
#
# Instruction
#
# 1. Run ADF Test on `df.spread` and with `maxlag` as `1`.

# %%
# To perform ADF Test
from statsmodels.tsa.stattools import adfuller
# Compute ADF test statistics
adf = adfuller(df['spread'],maxlag=1)
adf[0]
# Out:
# -2.5496573051932754

# %%
adf[4]
# Out:
# {'1%': -3.4416553818946145,
#  '5%': -2.8665274458710064,
#  '10%': -2.5694261699959413}

# %% [markdown]
# If t-stat value is less than the critical value then the spread is cointegrated.
#
# Instructions
# 2. Replace `..2..` with `True` if the spread is cointegrated and `False` if the spread is not cointegrated
# (Assume 90% confidence level)

# %%
is_triplet_cointegrated = False

# %% [markdown]
# ## 5. Mean reversion strategy

# %%
def stat_arb(df, lookback, std_dev):
    df['moving_average'] = df.spread.rolling(lookback).mean()
    df['moving_std_dev'] = df.spread.rolling(lookback).std()

    df['upper_band'] = df.moving_average + std_dev*df.moving_std_dev
    df['lower_band'] = df.moving_average - std_dev*df.moving_std_dev

    df['long_entry'] = df.spread < df.lower_band
    df['long_exit'] = df.spread >= df.moving_average
    df['positions_long'] = np.nan
    df.loc[df.long_entry, 'positions_long'] = 1
    df.loc[df.long_exit, 'positions_long'] = 0
    df.positions_long = df.positions_long.fillna(method='ffill')

    df['short_entry'] = df.spread > df.upper_band
    df['short_exit'] = df.spread <= df.moving_average
    df['positions_short'] = np.nan
    df.loc[df.short_entry, 'positions_short'] = -1
    df.loc[df.short_exit, 'positions_short'] = 0
    df.positions_short = df.positions_short.fillna(method='ffill')

    df['positions'] = df.positions_long + df.positions_short

    df['spread_difference'] = df.spread - df.spread.shift(1)
    df['pnl'] = df.positions.shift(1) * df.spread_difference
    df['cumpnl'] = df.pnl.cumsum()
    return df

# %% [markdown]
# Instruction
# 1. Call the function stat_arb with df, lookback as 15 and standard deviation as 1.

# %%
df = stat_arb(df,15,1)

df.head(30)
# Out:
#                    GLD        GDX    USO     spread  moving_average  \
# Date
# 2017-01-03  110.470001  21.472231  11.44  -0.562185             NaN
# 2017-01-04  110.860001  21.630116  11.58  -1.029272             NaN
# 2017-01-05  112.580002  22.893188  11.70  -5.438168             NaN
# 2017-01-06  111.750000  22.093899  11.68  -2.430430             NaN
# 2017-01-09  112.669998  22.162973  11.31  -1.571559             NaN
# 2017-01-10  113.150002  22.320860  11.07  -1.672104             NaN
# 2017-01-11  113.500000  22.271519  11.37  -1.304423             NaN
# 2017-01-12  113.910004  22.320860  11.54  -1.254147             NaN
# 2017-01-13  114.209999  22.439270  11.41  -1.425927             NaN
# 2017-01-17  115.849998  23.051071  11.43  -2.726869             NaN
# 2017-01-18  114.870003  22.705700  11.16  -1.858380             NaN
# 2017-01-19  114.769997  22.577419  11.17  -1.352066             NaN
# 2017-01-20  115.050003  22.814245  11.39  -2.364960             NaN
# 2017-01-23  115.790001  23.495119  11.32  -4.830797             NaN
# 2017-01-24  115.269997  23.514856  11.37  -5.481596       -2.353526
# 2017-01-25  114.320000  23.159616  11.31  -4.688732       -2.628629
# 2017-01-26  113.260002  22.567551  11.53  -3.076852       -2.765134
# 2017-01-12             NaN        False       False              NaN
# 2017-01-13             NaN        False       False              NaN
# 2017-01-17             NaN        False       False              NaN
# 2017-01-18             NaN        False       False              NaN
# 2017-01-19             NaN        False       False              NaN
# 2017-01-20             NaN        False       False              NaN
# 2017-01-23             NaN        False       False              NaN
# 2017-01-24             1.0        False        True              0.0
# 2017-01-25             1.0        False        True              0.0
# 2017-01-26             1.0        False        True              0.0
# 2017-01-27             1.0        False        True              0.0
# 2017-01-30             1.0        False        True              0.0
# 2017-01-31             1.0        False        True              0.0
# 2017-02-01             1.0        False        True              0.0
# 2017-02-02             1.0        False        True              0.0
# 2017-02-03             1.0        False        True              0.0
# 2017-02-06             1.0        False        True              0.0
# 2017-02-07             1.0        False        True              0.0
# 2017-02-08             1.0        False        True              0.0
# 2017-02-09             1.0        False        True              0.0
# 2017-02-10             1.0        False        True              0.0
# 2017-02-13             1.0        False        True              0.0
# 2017-02-14             1.0        False        True              0.0
#
#             positions  spread_difference       pnl    cumpnl
# Date
# 2017-01-03        NaN                NaN       NaN       NaN
# 2017-01-04        NaN          -0.467086       NaN       NaN
# 2017-01-05        NaN          -4.408896       NaN       NaN
# 2017-01-06        NaN           3.007738       NaN       NaN
# 2017-01-09        NaN           0.858871       NaN       NaN
# 2017-01-10        NaN          -0.100545       NaN       NaN
# 2017-01-11        NaN           0.367681       NaN       NaN
# 2017-01-12        NaN           0.050276       NaN       NaN
# 2017-01-13        NaN          -0.171779       NaN       NaN
# 2017-01-17        NaN          -1.300942       NaN       NaN
# 2017-01-18        NaN           0.868489       NaN       NaN
# 2017-01-19        NaN           0.506314       NaN       NaN
# 2017-01-20        NaN          -1.012894       NaN       NaN
# 2017-01-23        NaN          -2.465837       NaN       NaN
# 2017-01-24        1.0          -0.650798       NaN       NaN
# 2017-01-25        1.0           0.792864  0.792864  0.792864
# 2017-01-26        1.0           1.611880  1.611880  2.404744
# 2017-01-27        1.0          -1.327385 -1.327385  1.077358
# 2017-01-30        1.0           0.897726  0.897726  1.975084
# 2017-01-31        1.0          -2.130685 -2.130685 -0.155601
# 2017-02-01        1.0          -0.088854 -0.088854 -0.244455
# 2017-02-02        1.0          -1.883411 -1.883411 -2.127866
# 2017-02-03        1.0          -0.298243 -0.298243 -2.426109
# 2017-02-06        1.0          -2.561528 -2.561528 -4.987637
# 2017-02-07        1.0           0.417467  0.417467 -4.570171
# 2017-02-08        1.0          -0.620700 -0.620700 -5.190871
# 2017-02-09        1.0           2.127863  2.127863 -3.063008
# 2017-02-10        1.0          -1.592768 -1.592768 -4.655776
# 2017-02-13        1.0           0.935794  0.935794 -3.719981
# 2017-02-14        1.0           0.227934  0.227934 -3.492047

# %% [markdown]
# ## 6. Plot the profit and loss (PnL)

# %% [markdown]
# Instruction
# 1. Plot the cumulative PnL

# %%
df["cumpnl"].plot(kind='line',figsize=[10,6])

plt.xlabel(xlabel="Datetime")
plt.ylabel(ylabel="Cummulative_profit")
plt.show()
