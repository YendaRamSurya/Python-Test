# %% [markdown]
# # Notebook Instructions
# <i>You can run the notebook document sequentially (one cell a time) by pressing <b> shift + enter</b>. While a cell is running, a [*] will display on the left. When it has been run, a number will display indicating the order in which it was run in the notebook [8].</i>
#
# <i>Enter edit mode by pressing <b>`Enter`</b> or using the mouse to click on a cell's editor area. Edit mode is indicated by a green cell border and a prompt showing in the editor area.</i>

# %% [markdown]
# # Mean Reversion Strategy on AUDCAD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')
plt.rcParams['figure.figsize'] = (10, 7)

# %%
df = pd.read_csv('AUDCAD.csv', index_col=0)
df.index = pd.to_datetime(df.index)

# %%
df.Close.plot()
plt.ylabel("AUDCAD")
plt.show()

# %% [markdown]
# ## Moving average and moving standard deviation

# %%
# Moving Average
df['moving_average'] = df.Close.rolling(5).mean()
# Moving Standard Deviation
df['moving_std_dev'] = df.Close.rolling(5).std()
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume  moving_average  \
# Date
# 2009-12-31  0.9429  0.9460  0.9380  0.9455     0.9455       0             NaN
# 2010-01-01  0.9455  0.9457  0.9440  0.9451     0.9451       0             NaN
# 2010-01-04  0.9393  0.9513  0.9362  0.9494     0.9494       0             NaN
# 2010-01-05  0.9498  0.9516  0.9458  0.9473     0.9473       0             NaN
# 2010-01-06  0.9473  0.9510  0.9465  0.9490     0.9490       0         0.94726
#
#             moving_std_dev  upper_band  lower_band  long_entry  long_exit  \
# Date
# 2009-12-31             NaN         NaN         NaN       False      False
# 2010-01-01             NaN         NaN         NaN       False      False
# 2010-01-04             NaN         NaN         NaN       False      False
# 2010-01-05             NaN         NaN         NaN       False      False
# 2010-01-06         0.00196     0.94824     0.94628       False       True
#
#             positions_long  short_entry  short_exit  positions_short  \
# Date
# 2009-12-31             NaN        False       False              NaN
# 2010-01-01             NaN        False       False              NaN
# 2010-01-04             NaN        False       False              NaN
# 2010-01-05             NaN        False       False              NaN
# 2010-01-06             0.0         True       False             -1.0
#
#             positions  percentage_change  strategy_returns  cumulative_returns
# Date
# 2009-12-31        NaN                NaN               NaN                 NaN
# 2010-01-01        NaN          -0.000423               NaN                 NaN
# 2010-01-04        NaN           0.004550               NaN                 NaN
# 2010-01-05        NaN          -0.002212               NaN                 NaN
# 2010-01-06       -1.0           0.001795               NaN                 NaN

# %% [markdown]
# ## Upper band and lower band

# %%
df['upper_band'] = df.moving_average + 0.5*df.moving_std_dev
df['lower_band'] = df.moving_average - 0.5*df.moving_std_dev
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume  moving_average  \
# Date
# 2009-12-31  0.9429  0.9460  0.9380  0.9455     0.9455       0             NaN
# 2010-01-01  0.9455  0.9457  0.9440  0.9451     0.9451       0             NaN
# 2010-01-04  0.9393  0.9513  0.9362  0.9494     0.9494       0             NaN
# 2010-01-05  0.9498  0.9516  0.9458  0.9473     0.9473       0             NaN
# 2010-01-06  0.9473  0.9510  0.9465  0.9490     0.9490       0         0.94726
#
#             moving_std_dev  upper_band  lower_band  long_entry  long_exit  \
# Date
# 2009-12-31             NaN         NaN         NaN       False      False
# 2010-01-01             NaN         NaN         NaN       False      False
# 2010-01-04             NaN         NaN         NaN       False      False
# 2010-01-05             NaN         NaN         NaN       False      False
# 2010-01-06         0.00196     0.94824     0.94628       False       True
#
#             positions_long  short_entry  short_exit  positions_short  \
# Date
# 2009-12-31             NaN        False       False              NaN
# 2010-01-01             NaN        False       False              NaN
# 2010-01-04             NaN        False       False              NaN
# 2010-01-05             NaN        False       False              NaN
# 2010-01-06             0.0         True       False             -1.0
#
#             positions  percentage_change  strategy_returns  cumulative_returns
# Date
# 2009-12-31        NaN                NaN               NaN                 NaN
# 2010-01-01        NaN          -0.000423               NaN                 NaN
# 2010-01-04        NaN           0.004550               NaN                 NaN
# 2010-01-05        NaN          -0.002212               NaN                 NaN
# 2010-01-06       -1.0           0.001795               NaN                 NaN

# %% [markdown]
# ## Long entry and exit

# %%
df['long_entry'] = df.Close < df.lower_band
df['long_exit'] = df.Close >= df.moving_average
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume  moving_average  \
# Date
# 2009-12-31  0.9429  0.9460  0.9380  0.9455     0.9455       0             NaN
# 2010-01-01  0.9455  0.9457  0.9440  0.9451     0.9451       0             NaN
# 2010-01-04  0.9393  0.9513  0.9362  0.9494     0.9494       0             NaN
# 2010-01-05  0.9498  0.9516  0.9458  0.9473     0.9473       0             NaN
# 2010-01-06  0.9473  0.9510  0.9465  0.9490     0.9490       0         0.94726
#
#             moving_std_dev  upper_band  lower_band  long_entry  long_exit  \
# Date
# 2009-12-31             NaN         NaN         NaN       False      False
# 2010-01-01             NaN         NaN         NaN       False      False
# 2010-01-04             NaN         NaN         NaN       False      False
# 2010-01-05             NaN         NaN         NaN       False      False
# 2010-01-06         0.00196     0.94824     0.94628       False       True
#
#             positions_long  short_entry  short_exit  positions_short  \
# Date
# 2009-12-31             NaN        False       False              NaN
# 2010-01-01             NaN        False       False              NaN
# 2010-01-04             NaN        False       False              NaN
# 2010-01-05             NaN        False       False              NaN
# 2010-01-06             0.0         True       False             -1.0
#
#             positions  percentage_change  strategy_returns  cumulative_returns
# Date
# 2009-12-31        NaN                NaN               NaN                 NaN
# 2010-01-01        NaN          -0.000423               NaN                 NaN
# 2010-01-04        NaN           0.004550               NaN                 NaN
# 2010-01-05        NaN          -0.002212               NaN                 NaN
# 2010-01-06       -1.0           0.001795               NaN                 NaN

# %% [markdown]
# ## Long Positions

# %%
df['positions_long'] = np.nan
df.loc[df.long_entry, 'positions_long'] = 1
df.loc[df.long_exit, 'positions_long'] = 0
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume  moving_average  \
# Date
# 2009-12-31  0.9429  0.9460  0.9380  0.9455     0.9455       0             NaN
# 2010-01-01  0.9455  0.9457  0.9440  0.9451     0.9451       0             NaN
# 2010-01-04  0.9393  0.9513  0.9362  0.9494     0.9494       0             NaN
# 2010-01-05  0.9498  0.9516  0.9458  0.9473     0.9473       0             NaN
# 2010-01-06  0.9473  0.9510  0.9465  0.9490     0.9490       0         0.94726
#
#             moving_std_dev  upper_band  lower_band  long_entry  long_exit  \
# Date
# 2009-12-31             NaN         NaN         NaN       False      False
# 2010-01-01             NaN         NaN         NaN       False      False
# 2010-01-04             NaN         NaN         NaN       False      False
# 2010-01-05             NaN         NaN         NaN       False      False
# 2010-01-06         0.00196     0.94824     0.94628       False       True
#
#             positions_long  short_entry  short_exit  positions_short  \
# Date
# 2009-12-31             NaN        False       False              NaN
# 2010-01-01             NaN        False       False              NaN
# 2010-01-04             NaN        False       False              NaN
# 2010-01-05             NaN        False       False              NaN
# 2010-01-06             0.0         True       False             -1.0
#
#             positions  percentage_change  strategy_returns  cumulative_returns
# Date
# 2009-12-31        NaN                NaN               NaN                 NaN
# 2010-01-01        NaN          -0.000423               NaN                 NaN
# 2010-01-04        NaN           0.004550               NaN                 NaN
# 2010-01-05        NaN          -0.002212               NaN                 NaN
# 2010-01-06       -1.0           0.001795               NaN                 NaN

# %% [markdown]
# ## Forward fill Long Positions

# %%
df.positions_long = df.positions_long.fillna(method='ffill')
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume  moving_average  \
# Date
# 2009-12-31  0.9429  0.9460  0.9380  0.9455     0.9455       0             NaN
# 2010-01-01  0.9455  0.9457  0.9440  0.9451     0.9451       0             NaN
# 2010-01-04  0.9393  0.9513  0.9362  0.9494     0.9494       0             NaN
# 2010-01-05  0.9498  0.9516  0.9458  0.9473     0.9473       0             NaN
# 2010-01-06  0.9473  0.9510  0.9465  0.9490     0.9490       0         0.94726
#
#             moving_std_dev  upper_band  lower_band  long_entry  long_exit  \
# Date
# 2009-12-31             NaN         NaN         NaN       False      False
# 2010-01-01             NaN         NaN         NaN       False      False
# 2010-01-04             NaN         NaN         NaN       False      False
# 2010-01-05             NaN         NaN         NaN       False      False
# 2010-01-06         0.00196     0.94824     0.94628       False       True
#
#             positions_long  short_entry  short_exit  positions_short  \
# Date
# 2009-12-31             NaN        False       False              NaN
# 2010-01-01             NaN        False       False              NaN
# 2010-01-04             NaN        False       False              NaN
# 2010-01-05             NaN        False       False              NaN
# 2010-01-06             0.0         True       False             -1.0
#
#             positions  percentage_change  strategy_returns  cumulative_returns
# Date
# 2009-12-31        NaN                NaN               NaN                 NaN
# 2010-01-01        NaN          -0.000423               NaN                 NaN
# 2010-01-04        NaN           0.004550               NaN                 NaN
# 2010-01-05        NaN          -0.002212               NaN                 NaN
# 2010-01-06       -1.0           0.001795               NaN                 NaN

# %% [markdown]
# ## Short positions

# %%
df['short_entry'] = df.Close > df.upper_band
df['short_exit'] = df.Close <= df.moving_average

df['positions_short'] = np.nan
df.loc[df.short_entry, 'positions_short'] = -1
df.loc[df.short_exit, 'positions_short'] = 0

df.positions_short = df.positions_short.fillna(method='ffill')

# %% [markdown]
# ## Positions

# %%
df['positions'] = df.positions_long + df.positions_short

# %% [markdown]
# ## Cumulative returns

# %%
df['percentage_change'] = df.Close.pct_change()
df['strategy_returns'] = df.positions.shift(1) * df.percentage_change
df['cumulative_returns'] = (df.strategy_returns+1).cumprod()

# %%
df.cumulative_returns.plot(label='Cumulative Returns', figsize=(10, 7))
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.show()

# %%
def calc_drawdown(cum_rets):
    # Calculate the running maximum
    running_max = np.maximum.accumulate(cum_rets.dropna())
    # Ensure the value never drops below 1
    running_max[running_max < 1] = 1
    # Calculate the percentage drawdown
    drawdown = (cum_rets)/running_max - 1
    return drawdown


def plot_drawdown(drawdown):
    fig = plt.figure(figsize=(10, 7))
    # Plot
    drawdown.plot(color='r')
    plt.ylabel('Returns')
    plt.fill_between(drawdown.index, drawdown, color='red')
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.2)
    plt.show()


drawdown = calc_drawdown(df.cumulative_returns)
print("The maximum drawdown is %.2f" % (drawdown.min()*100))
plot_drawdown(drawdown)
# Out:
# The maximum drawdown is -11.25

# %% [markdown]
# Next step: Try this strategy on EURCHF.
