# %% [markdown]
# #### https://gist.github.com/yhilpisch/e214d02c060c3ca236f3b8d71cff0114
#
# Listed above is the gist link for the modelling course by Dr yves hilpch

# %% [markdown]
# ### intresting part from the lecture is the beauty of the professor in going through the course in a gist .
#
# - Yves is a diploma and a great at coding a good experience in using python for more than 5 years
# - Usage of AI for finance
#
# Python for finance is the good book and an advanced one a good read
#
# books on derivative analysis and variance of derivatives using python and python codes
#
# - `The area we live in is data driven finance and our greatest threat is efficient markets`
# - But all the data driven finance requires lot of infrastructure
# - Even as retail traders we can have a cloud a docker which would cost a lot in history
#
#
# - Should look up to bash programming and docker creation and setting up passwords for the jupyter notebook
#
# - Secondly using the usage of nomkl for numpy pandas and all to make it faster
#
# - Usage of Xonsh -- python shell for both python and shell scripting in place and like a virtual environment

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
f,ax1 = plt.subplots();
plt.style.use('seaborn')
url = 'http://hilpisch.com/aiif_eikon_eod_data.csv'
pd.set_option('mode.chained_assignment', None)

# %%
df = pd.read_csv(url,index_col=0,parse_dates=True)
df.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
df.dropna(axis=0,how='any')
# Out:
#                 AAPL.O   MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX  \
# Date
# 2010-01-04   30.572827   30.950   20.88   133.90  173.08  113.33  1132.99
# 2010-01-05   30.625684   30.960   20.87   134.69  176.14  113.63  1136.52
# 2010-01-06   30.138541   30.770   20.80   132.25  174.26  113.71  1137.14
# 2010-01-07   30.082827   30.452   20.60   130.00  177.67  114.19  1141.69
# 2010-01-08   30.282827   30.660   20.83   133.52  174.31  114.57  1144.98
# ...                ...      ...     ...      ...     ...     ...      ...
# 2019-12-24  284.270000  157.380   59.41  1789.21  229.91  321.23  3223.38
# 2019-12-26  289.910000  158.670   59.82  1868.77  231.21  322.94  3239.91
# 2019-12-27  289.800000  158.960   60.08  1869.80  230.66  322.86  3240.02
# 2019-12-30  291.520000  157.590   59.62  1846.89  229.80  321.08  3221.29
# 2019-12-31  293.650000  157.700   59.85  1847.84  229.93  321.86  3230.78
#
#              .VIX    EUR=       XAU=    GDX     GLD
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2609 entries, 2010-01-01 to 2020-01-01
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2516 non-null   float64
#  1   MSFT.O  2516 non-null   float64
#  2   INTC.O  2516 non-null   float64
#  3   AMZN.O  2516 non-null   float64
#  4   GS.N    2516 non-null   float64
#  5   SPY     2516 non-null   float64
#  6   .SPX    2516 non-null   float64
#  7   .VIX    2516 non-null   float64
#  8   EUR=    2609 non-null   float64
#  9   XAU=    2602 non-null   float64
#  10  GDX     2516 non-null   float64
#  11  GLD     2516 non-null   float64
# dtypes: float64(12)
# memory usage: 265.0 KB

# %%
(df/df.iloc[0]).plot(figsize =(10,6))
plt.legend(df.columns,loc=1)

# %%
# lagging the data
sym ="AAPL.O"

sf = df[sym]

# %%
sf.head()
# Out:
# Date
# 2010-01-04    30.572827
# 2010-01-05    30.625684
# 2010-01-06    30.138541
# 2010-01-07    30.082827
# 2010-01-08    30.282827
# Name: AAPL.O, dtype: float64

# %%
lag =5
cols =list()

for lag in range(1,lag+1):
    col = f"lags_{lag}"
    sf[col] = sf.shift(lag)
    cols.append(col)

# %%
cols
# Out:
# ['lags_1', 'lags_2', 'lags_3', 'lags_4', 'lags_5']

# %%
np.arange()
