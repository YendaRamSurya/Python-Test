# %% [markdown]
# # Objective:
# 1. Tune parameters short_window and long_window to maximize profit
# 2. Learn signal generation

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['axes.grid'] = False
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import HTML

# %%
class CROSSOVER:
    ## class attribute: We can know the possible values for moving_average and metrics 
    ## before creating an object of the class 
    moving_average = ("Simple","exponential") 
    metrics = {'Sharpe':'Sharpe Ratio',
               'CAGR':'Compound Average Growth Rate',
               'MDD':'Maximum Drawdown',
               'NHR':'Normalized Hit Ratio',
               'OTS':'Optimal trade size'}
    
    def __init__(self,data,short_window = 5, long_window = 40,
                 moving_average = "Simple", data_name = None, start = None,end = None ):

        """
         Doc string of the class. We define what class is about here
        """
        self.data=data #the dataframe
        self.data['yr'] = self.data['Date'].dt.year
        self.moving_average = moving_average
        if data_name is None: #the name that will appear on plots
            self.data_name = moving_average
        else:
            self.data_name=data_name
        self.short_window = short_window
        self.long_window = long_window
        self.n_days = (self.data.Date.iloc[-1] - self.data.Date.iloc[0])
        self.start=start #the beginning date of the sample period
        self.end=end #the ending date of the sample period

    def generate_signals(self, charts=True, burn=False):
        """
        This is an instance method. Only works on an object.
        """
        if self.long_window <= self.short_window: return

        if self.moving_average == "Simple":
            self.data["SMA"] = self.data.Close.rolling(self.short_window).mean()
            self.data["LMA"] = self.data.Close.rolling(self.long_window).mean()
        elif self.moving_average == "exponential":
            self.data["SMA"] = self.data.Close.ewm(span = self.short_window, adjust=True).mean()
            self.data["LMA"] = self.data.Close.ewm(span = self.long_window, adjust=True).mean()
        else:
            raise Exception("Not a valid type")

        self.data["_lag1_SMA"] = self.data.SMA.shift(1)
        self.data["_lag1_LMA"] = self.data.LMA.shift(1)

        ## creating signal    
        buy_mask = (self.data.SMA > self.data.LMA) & (self.data._lag1_SMA < self.data._lag1_LMA)
        sell_mask = (self.data.SMA < self.data.LMA) & (self.data._lag1_SMA > self.data._lag1_LMA)

        self.data['signal'] = np.nan
        self.data.loc[buy_mask,'signal'] = +1
        self.data.loc[sell_mask,'signal'] = -1
        if burn:
            burn_period = 2*self.long_window
            self.data.loc[:burn_period,"signal"] = np.nan
        self.data.signal = self.data.signal.fillna(method="ffill")

        mask = (self.data.signal != self.data.signal.shift(1)) & (self.data.signal.notnull())
        self.data['trade_num'] = np.where(mask,1,0).cumsum()

        ## display chart
        if charts:
            plt.plot(self.data['Date'],self.data['SMA'],color='black', label=f'SMA ={self.short_window}')
            plt.plot(self.data['Date'],self.data['LMA'],color='blue', label=f'LMA ={self.long_window}')
            plt.title('%s Strategy Backtest'%(self.data_name))
            plt.legend(loc=0)
            d_color = {}
            d_color[1] = '#90ee90'  ## light green
            d_color[-1] = "#ffcccb" ## light red

            j = 0
            for i in range(1,self.data.shape[0]):
                if np.isnan(self.data.signal[i-1]):
                    j=i
                elif (self.data.signal[i-1] == self.data.signal[i]) and (i< (self.data.shape[0]-1)):
                    continue
                else:
                    plt.axvspan(self.data['Date'][j], self.data['Date'][i], 
                               alpha=0.5, color=d_color[self.data.signal[i-1]], label="interval")
                    j = i
            plt.show()
        
    def signal_performance(self, allocation):
        """
        Another instance method
        """
        if self.long_window <= self.short_window: return
        self.allocation=allocation

        #creating returns and portfolio value series
        self.data['Return']=np.log(self.data['Close']/self.data['Close'].shift(1))
        self.data['S_Return']=self.data['signal'].shift(1)*self.data['Return']
        self.data['Market_Return']=self.data['Return'].expanding().sum()
        self.data['Strategy_Return']=self.data['S_Return'].expanding().sum()
        self.data['Portfolio Value']=((self.data['Strategy_Return']+1)*self.allocation)
        self.data['Wins']=np.where(self.data['S_Return'] > 0,1,0)
        self.data['Losses']=np.where(self.data['S_Return']<0,1,0)

        ## Daywise Performance
        d_perform = {}
        d_perform['TotalWins']=self.data['Wins'].sum()
        d_perform['TotalLosses']=self.data['Losses'].sum()
        d_perform['TotalTrades']=d_perform['TotalWins']+d_perform['TotalLosses']
        d_perform['HitRatio']=round(d_perform['TotalWins']/d_perform['TotalTrades'],2)
        d_perform['SharpeRatio'] = self.data["S_Return"].mean() / self.data["S_Return"].std() * (252**.5)        
        d_perform['CAGR'] = (1+self.data['Strategy_Return']).iloc[-1]**(365.25/self.n_days.days) -1
        d_perform['MaxDrawdown']=(1.0-self.data['Portfolio Value']/self.data['Portfolio Value'].cummax()).max()
        self.daywise_performance = pd.Series(d_perform)

        ## Tradewise performance
        _df = self.data.groupby(["signal","trade_num"]).S_Return.sum().reset_index()
        _df['Wins']=np.where(_df['S_Return'] > 0,1,0)
        _df['Losses']=np.where(_df['S_Return']<0,1,0)
        d_tp = {}
        d_tp.update(_df[["Wins","Losses"]].sum().rename({'Wins':'TotalWins','Losses':'TotalLosses'}).to_dict())
        d_tp['TotalTrades'] = d_tp["TotalWins"] + d_tp["TotalLosses"]
        d_tp['HitRatio'] =  np.round(d_tp["TotalWins"] / d_tp['TotalTrades'],4)
        d_tp['AvgWinRet'] = np.round(_df[_df.Wins==1].S_Return.mean(),4)
        d_tp['AvgLossRet'] = np.round(_df[_df.Losses==1].S_Return.mean(),4)
        d_tp['WinByLossRet'] = np.round(abs(d_tp['AvgWinRet']/d_tp['AvgLossRet']),2)
        d_tp['RetVar'] = np.round(_df.S_Return.std(),4)
        _sum = _df.groupby("Wins").S_Return.sum()
        d_tp['NormHitRatio'] = np.round(_sum[1]/_sum.abs().sum(),4)
        d_tp['OptimalTradeSize'] = self.kelly(p = d_tp['HitRatio'], b = d_tp['WinByLossRet'])
        self.tradewise_performance = pd.Series(d_tp)

    @staticmethod
    def kelly(p,b):
        """
        Static method: No object or class related arguments
        p: win prob, b: net odds received on wager, output(f*) = p - (1-p)/b

        Spreadsheet example
            from sympy import symbols, solve, diff
            x = symbols('x')
            y = (1+3.3*x)**37 *(1-x)**63
            solve(diff(y, x), x)[1]
        Shortcut
            .37 - 0.63/3.3
        """
        return np.round(p - (1-p)/b,4)

    def plot_performance(self, allocation=1):
        #intializing a variable for initial allocation
        #to be used to create equity curve
        self.signal_performance(allocation)
        
        #yearly performance
        self.yearly_performance()
        
        #Plotting the Performance of the strategy
        plt.plot(self.data['Date'],self.data['Market_Return'],color='black', label='Market Returns')
        plt.plot(self.data['Date'],self.data['Strategy_Return'],color='blue', label= 'Strategy Returns')
        plt.title('%s Strategy Backtest'%(self.data_name))
        plt.legend(loc=0)
        plt.tight_layout()
        plt.show()

        plt.plot(self.data['Date'],self.data['Portfolio Value'], color='blue')
        plt.title('%s Portfolio Value'%(self.data_name))
        plt.show()
        
    def yearly_performance(self):
        """
        Instance method
        Adds an instance attribute: yearly_df
        """
        _yearly_df = self.data.groupby(['yr','signal']).S_Return.sum().unstack()
        _yearly_df.rename(columns={-1.0:'Sell',1.0:'Buy'}, inplace=True)
        _yearly_df['Return'] = _yearly_df.sum(1)

        # yearly_df
        self.yearly_df = _yearly_df.style.bar(color=["#ffcccb",'#90ee90'], align = 'zero').format({
            'Sell': '{:,.2%}'.format,'Buy': '{:,.2%}'.format,'Return': '{:,.2%}'.format})
    
    def update_metrics(self):
        """
        Called from the SMA_LMA_matrix class method
        """
        d_field = {}
        if self.long_window > self.short_window:
            d_field['Sharpe'] = self.daywise_performance.SharpeRatio
            d_field['CAGR'] = self.daywise_performance.CAGR
            d_field['MDD'] = self.daywise_performance.MaxDrawdown
            d_field['NHR'] = self.tradewise_performance.NormHitRatio
            d_field['OTS'] = self.tradewise_performance.OptimalTradeSize
            
        return d_field
    
    @classmethod
    def SMA_LMA_matrix(cls,data, LMA_range, SMA_range, metrics, moving_average = "Simple", optimal_sol = True):
        """
        This is a class method. First argument is a class.
        """
        c_green = sns.light_palette("green", as_cmap=True)
        c_red = sns.light_palette("red", as_cmap=True)
        
        d_mats = {m:[] for m in metrics}
        
        for l in LMA_range:
            d_row = {m:[] for m in metrics}
            for s in SMA_range:
                obj = cls(data, s, l, moving_average) ## object being created from the class
                obj.generate_signals(charts=False)
                obj.signal_performance(100)
                d_field = obj.update_metrics()
                for m in metrics: d_row[m].append(d_field.get(m,np.nan))
            for m in metrics: d_mats[m].append(d_row[m])
                
        d_df = {m:pd.DataFrame(d_mats[m], index=LMA_range, columns=SMA_range) for m in metrics}

        def optimal(_df):
            """ 
            This is a function inside a function.
            We could have created it outside the class if needed, but that would made it harder to relate. 
            """
            _df = _df.stack().rank()
            _df = (_df - _df.mean())/_df.std()
            return _df.unstack()

        if optimal_sol:
            d_df['Signal'] = 0
            if 'Sharpe' in metrics: d_df['Signal'] += 2*optimal(d_df['Sharpe'])
            if 'NHR' in metrics: d_df['Signal'] += optimal(d_df['NHR'])
            if 'CAGR' in metrics: d_df['Signal'] += optimal(d_df['CAGR'])
            if 'MDD' in metrics: d_df['Signal'] -= 2*optimal(d_df['MDD'])
            l_i,s_i = np.unravel_index(np.argmax(d_df['Signal'].values), d_df['Signal'].shape)
            print(f"Most optimal cross-over pair is SMA:{SMA_range[s_i]}, LMA:{LMA_range[l_i]}")
            metrics.insert(0,'Signal')

        for m in metrics:
            display(HTML(d_df[m].style.background_gradient(axis=None, cmap=
                c_red if m=="MDD" else c_green).format(
                ("{:,.2}" if m in ["Sharpe","Signal"] else "{:.2%}")).set_caption(m).render()))
            
        return d_df

# %%
close_df = pd.read_csv("class_data.csv", parse_dates = [0])

# %%
close_df.head()
# Out:
#         Date   Close
# 0 2000-01-03  1592.2
# 1 2000-01-04  1638.7
# 2 2000-01-05  1595.8
# 3 2000-01-06  1617.6
# 4 2000-01-07  1613.3

# %%
close_df.Close.ewm(span = 20, adjust=False, min_periods=20).mean()
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 4230    8107.503277
# 4231    8100.393441
# 4232    8094.151208
# 4233    8095.051093
# 4234    8103.693846
# Name: Close, Length: 4235, dtype: float64

# %%
CROSSOVER.metrics
# Out:
# {'Sharpe': 'Sharpe Ratio',
#  'CAGR': 'Compound Average Growth Rate',
#  'MDD': 'Maximum Drawdown',
#  'NHR': 'Normalized Hit Ratio',
#  'OTS': 'Optimal trade size'}

# %%
CROSSOVER.moving_average
# Out:
# ('Simple', 'exponential')

# %%
# Possible values for metrics : 'Sharpe','CAGR','MDD','NHR','OTS'
_= CROSSOVER.SMA_LMA_matrix(close_df, SMA_range=range(5,21), LMA_range=range(25,90,5),
                    metrics = ['Sharpe','MDD','OTS'], moving_average='exponential')
# Out:
# Most optimal cross-over pair is SMA:5, LMA:30
# <style  type="text/css" >
#     #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col0 {
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col1 {
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col2 {
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col3 {
#             background-color:  #068306;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col4 {
#             background-color:  #0c860c;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col5 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col6 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col7 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col8 {
#             background-color:  #349d34;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col9 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col10 {
#             background-color:  #359d35;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col11 {
#             background-color:  #299729;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col12 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col13 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col14 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row0_col15 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col1 {
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col2 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col3 {
#             background-color:  #209220;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col4 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col5 {
#             background-color:  #349d34;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col6 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col7 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col8 {
#             background-color:  #3aa03a;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col9 {
#             background-color:  #45a645;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col10 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col11 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col12 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col13 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col14 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row1_col15 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col0 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col1 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col2 {
#             background-color:  #219221;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col3 {
#             background-color:  #54ae54;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col4 {
#             background-color:  #229322;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col5 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col6 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col7 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col8 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col9 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col10 {
#             background-color:  #58b158;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col11 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col12 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col13 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col14 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row2_col15 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col0 {
#             background-color:  #0c860c;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col1 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col2 {
#             background-color:  #1d901d;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col3 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col4 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col5 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col6 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col7 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col8 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col9 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col10 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_77797450_a4fb_11ea_9887_b88198dfbc26row3_col11 {
#             background-color:  #61b661;
# <style  type="text/css" >
#     #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col0 {
#             background-color:  #41a441;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col1 {
#             background-color:  #1b8f1b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col2 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col3 {
#             background-color:  #44a544;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col4 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col5 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col6 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col7 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col8 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col9 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col10 {
#             background-color:  #6ebd6e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col11 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col12 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col13 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col14 {
#             background-color:  #92d192;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row0_col15 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col0 {
#             background-color:  #198e19;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col1 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col2 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col3 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col4 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col5 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col6 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col7 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col8 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col9 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col10 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col11 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col12 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col13 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col14 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row1_col15 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col0 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col1 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col2 {
#             background-color:  #62b662;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col3 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col4 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col5 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col6 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col7 {
#             background-color:  #92d192;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col8 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col9 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col10 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col11 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col12 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col13 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col14 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row2_col15 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col0 {
#             background-color:  #44a544;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col1 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col2 {
#             background-color:  #48a848;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col3 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col4 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col5 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col6 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col7 {
#             background-color:  #91d091;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col8 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col9 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col10 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_7780e94a_a4fb_11ea_81be_b88198dfbc26row3_col11 {
#             background-color:  #98d498;
# <style  type="text/css" >
#     #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col0 {
#             background-color:  #ffdbdb;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col1 {
#             background-color:  #ffd7d7;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col2 {
#             background-color:  #ffd2d2;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col3 {
#             background-color:  #ffc5c5;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col4 {
#             background-color:  #ffc6c6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col5 {
#             background-color:  #ffb7b7;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col6 {
#             background-color:  #ff9c9c;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col7 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col8 {
#             background-color:  #ffaeae;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col9 {
#             background-color:  #ff9a9a;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col10 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col11 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col12 {
#             background-color:  #ff8f8f;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col13 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col14 {
#             background-color:  #ff8585;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row0_col15 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col1 {
#             background-color:  #ffc6c6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col2 {
#             background-color:  #ffc4c4;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col3 {
#             background-color:  #ff9999;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col4 {
#             background-color:  #ff8888;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col5 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col6 {
#             background-color:  #ffb0b0;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col7 {
#             background-color:  #ff6e6e;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col8 {
#             background-color:  #ff9393;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col9 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col10 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col11 {
#             background-color:  #ff8b8b;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col12 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col13 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col14 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row1_col15 {
#             background-color:  #ffadad;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col0 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col1 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col2 {
#             background-color:  #ff9a9a;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col3 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col4 {
#             background-color:  #ffb0b0;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col5 {
#             background-color:  #ff9090;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col6 {
#             background-color:  #ff8787;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col7 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col8 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col9 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col10 {
#             background-color:  #ff9595;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col11 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col12 {
#             background-color:  #ff9b9b;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col13 {
#             background-color:  #ffabab;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col14 {
#             background-color:  #ffa4a4;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row2_col15 {
#             background-color:  #ffa4a4;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col0 {
#             background-color:  #ffa7a7;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col1 {
#             background-color:  #ffb4b4;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col2 {
#             background-color:  #ff9797;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col3 {
#             background-color:  #ff7d7d;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col4 {
#             background-color:  #ff9898;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col5 {
#             background-color:  #ff8585;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col6 {
#             background-color:  #ff8080;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col7 {
#             background-color:  #ff8c8c;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col8 {
#             background-color:  #ff9c9c;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col9 {
#             background-color:  #ff9898;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col10 {
#             background-color:  #ff9898;
#             color:  #000000;
#         }    #T_778af4a4_a4fb_11ea_bfa9_b88198dfbc26row3_col11 {
#             background-color:  #ff9a9a;
# <style  type="text/css" >
#     #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col0 {
#             background-color:  #6fbd6f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col1 {
#             background-color:  #50ac50;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col2 {
#             background-color:  #49a849;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col3 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col4 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col5 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col6 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col7 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col8 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col9 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col10 {
#             background-color:  #55af55;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col11 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col12 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col13 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col14 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row0_col15 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col0 {
#             background-color:  #4eab4e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col1 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col2 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col3 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col4 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col5 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col6 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col7 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col8 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col9 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col10 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col11 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col12 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col13 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col14 {
#             background-color:  #91d091;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row1_col15 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col0 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col1 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col2 {
#             background-color:  #6abb6a;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col3 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col4 {
#             background-color:  #6ebd6e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col5 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col6 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col7 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col8 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col9 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col10 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col11 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col12 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col13 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col14 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row2_col15 {
#             background-color:  #a1d9a1;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col0 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col1 {
#             background-color:  #2b982b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col2 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col3 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col4 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col5 {
#             background-color:  #91d091;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col6 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col7 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col8 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col9 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col10 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_7794d8d0_a4fb_11ea_9aac_b88198dfbc26row3_col11 {
#             background-color:  #94d294;

# %%
ema_strategy = CROSSOVER(close_df, moving_average='exponential', short_window = 15, long_window = 25)

# %%
ema_strategy.generate_signals()

# %%
ema_strategy.data
# Out:
#            Date    Close    yr          SMA          LMA    _lag1_SMA  \
# 0    2000-01-03  1592.20  2000  1592.200000  1592.200000          NaN
# 1    2000-01-04  1638.70  2000  1617.000000  1616.380000  1592.200000
# 2    2000-01-05  1595.80  2000  1608.971598  1608.964179  1617.000000
# 3    2000-01-06  1617.60  2000  1611.577935  1611.388831  1608.971598
# 4    2000-01-07  1613.30  2000  1612.019861  1611.834564  1611.577935
# ...         ...      ...   ...          ...          ...          ...
# 4230 2016-12-26  7908.25  2016  8080.940771  8133.922865  8105.610881
# 4231 2016-12-27  8032.85  2016  8074.929425  8126.148029  8080.940771
# 4232 2016-12-28  8034.85  2016  8069.919497  8119.125104  8074.929425
# 4233 2016-12-29  8103.60  2016  8074.129560  8117.930865  8069.919497
# 4234 2016-12-30  8185.80  2016  8088.088365  8123.151568  8074.129560
#
#         _lag1_LMA  signal  trade_num
# 0             NaN     NaN          0
# 1     1592.200000     NaN          0
# 2     1616.380000     NaN          0
# 3     1608.964179     NaN          0
# 4     1611.388831     NaN          0
# ...           ...     ...        ...
# 4230  8152.728937    -1.0        105
# 4231  8133.922865    -1.0        105
# 4232  8126.148029    -1.0        105
# 4233  8119.125104    -1.0        105
# 4234  8117.930865    -1.0        105
#
# [4235 rows x 9 columns]

# %%
ema_strategy.plot_performance(100)d

# %%
ema_strategy.daywise_performance
# Out:
# TotalWins      2175.000000
# TotalLosses    2048.000000
# TotalTrades    4223.000000
# HitRatio          0.520000
# SharpeRatio       0.460614
# CAGR              0.063632
# MaxDrawdown       0.392949
# dtype: float64

# %%
ema_strategy.tradewise_performance
# Out:
# TotalWins            44.0000
# TotalLosses          61.0000
# TotalTrades         105.0000
# HitRatio              0.4190
# AvgWinRet             0.0978
# AvgLossRet           -0.0402
# WinByLossRet          2.4300
# RetVar                0.1038
# NormHitRatio          0.6371
# OptimalTradeSize      0.1799
# dtype: float64

# %%
ema_strategy.yearly_df
# Out:
# <style  type="text/css" >
#     #T_9e677328_a409_11ea_9980_b88198dfbc26row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #ffcccb 45.0%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, #ffcccb 32.0%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.6%, #ffcccb 30.6%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 78.6%, transparent 78.6%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 54.7%, transparent 54.7%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 67.9%, transparent 67.9%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 62.7%, transparent 62.7%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 59.1%, transparent 59.1%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 64.6%, transparent 64.6%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 55.9%, transparent 55.9%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 61.9%, transparent 61.9%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 61.2%, transparent 61.2%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 66.2%, transparent 66.2%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.9%, #ffcccb 27.9%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 65.1%, transparent 65.1%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 53.8%, transparent 53.8%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.1%, #ffcccb 23.1%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 74.7%, transparent 74.7%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 60.6%, transparent 60.6%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.6%, transparent 52.6%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 80.8%, transparent 80.8%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 80.3%, transparent 80.3%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 100.0%, transparent 100.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.2%, #ffcccb 27.2%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 52.1%, transparent 52.1%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 9.8%, #ffcccb 9.8%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 70.2%, transparent 70.2%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 50.1%, transparent 50.1%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.0%, #ffcccb 38.0%, #ffcccb 50.0%, transparent 50.0%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 57.5%, transparent 57.5%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 51.5%, transparent 51.5%);
#         }    #T_9e677328_a409_11ea_9980_b88198dfbc26row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #90ee90 50.0%, #90ee90 67.3%, transparent 67.3%);
#         }    #T_9e6

# %%
_df =close_df.groupby(["signal","trade_num"]).S_Return.sum().reset_index()


_df['Wins']=np.where(_df['S_Return'] > 0,1,0)
_df['Losses']=np.where(_df['S_Return']<0,1,0)
d_tp = {}
d_tp.update(_df[["Wins","Losses"]].sum().rename({'Wins':'TotalWins','Losses':'TotalLosses'}).to_dict())
d_tp
# Out:
# {'TotalWins': 18, 'TotalLosses': 37}
